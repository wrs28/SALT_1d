# %%
if length(LOAD_PATH) < 3
    push!(LOAD_PATH,"/Users/wrsweeney/Box Sync/Research/SALT")
#    push!(LOAD_PATH,"/home/wrs28/Documents/SALT")
end

# if nprocs() == 1
#     addprocs(3)
#     addprocs(20)
# end

using SALT_2d_plus
;

# %%
M₋ = (inputs.∂R[1] .≤ inputs.x̄_ext[1] .≤ inputs.∂R[2]) .& (inputs.∂R[3] .≤ inputs.x̄_ext[2] .≤ inputs.∂R[4])
# Out:
# 227529-element BitArray{1}:
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#      ⋮
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false
#  false

# %%
include("SALT_2d_inputs.jl")
inputs = processInputs(
    geometry, geoParams, n₁, n₂, scatteringRegions, wgd, wgp, wgt, wge,
    F, D₀, k₀, γ⟂,
    ∂R, bc, bk, input_modes,
    ∂S₊, ∂S₋, channels, a,
    coord, N, subPixelNum);
;

# %%
updateInputs!(inputs,:∂S₋,.05)
updateInputs!(inputs,:a,Complex128[1.,1.,0.,0.])
ψ,φ,A,inputs_s = compute_scatter(inputs,10)#; A=A)
;

# %%
wavePlot(ψ,inputs)
wavePlot(φ,inputs)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x126f1b310>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x127187450>)
# ([-0.881481, -0.877778, -0.874074, -0.87037, -0.866667, -0.862963, -0.859259, -0.855556, -0.851852, -0.848148  …  0.848148, 0.851852, 0.855556, 0.859259, 0.862963, 0.866667, 0.87037, 0.874074, 0.877778, 0.881481], [-0.881481, -0.877778, -0.874074, -0.87037, -0.866667, -0.862963, -0.859259, -0.855556, -0.851852, -0.848148  …  0.848148, 0.851852, 0.855556, 0.859259, 0.862963, 0.866667, 0.87037, 0.874074, 0.877778, 0.881481], Complex{Float64}[0.0+0.0im 0.0+0.0im … 0.0-0.0im 0.0-0.0im; 0.0+0.0im 0.0+0.0im … 0.0-0.0im 0.0-0.0im; … ; 0.0+0.0im 0.0+0.0im … -0.0+0.0im -0.0+0.0im; 0.0+0.0im 0.0+0.0im … -0.0+0.0im -0.0+0.0im])
